# %% [markdown]
# <a href="https://colab.research.google.com/github/TenzinYangzom158/Gaana-Data-Analysis/blob/main/Gaana_com_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gaana.com Data Analysis**

# %%
# !git clone https://github.com/AshishJangra27/Gaana-Data-Analysis
# Out:
# fatal: destination path 'Gaana-Data-Analysis' already exists and is not an empty directory.

# %%
import pandas as pd
df = pd.read_csv('Gaana-Data-Analysis/songs.csv')
from tqdm import tqdm # tells how much time whole program will take to execute

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.head() # 5 dataset
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df.head(10)
# Out:
#                                                 name  \
# 0                              Dil - E - Nadan Tujhe
# 1                  Agar Hum Kahen Aur Woh Muskara De
# 2                                      Unke Dekhe Se
# 3            Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                            Hazaron Khwahishen Aisi
# 5               Suna Tha Ki Woh Aayenge Anjuman Mein
# 6  Bahut Pahele Se Un Qadmon Ki Aahat Jaan Lete Hain
# 7                        Tum Itna Jo Muskura Rahe Ho
# 8                           Tum Apna Ranjhogham Apni
# 9                    Dialogues And Ishq Mujhko Nahin
#
#                           singer  \
# 0      Chitra Singh|Jagjit Singh
# 1      Chitra Singh|Jagjit Singh
# 2                   Jagjit Singh
# 3                   Chitra Singh
# 4                   Jagjit Singh
# 5      Chitra Singh|Jagjit Singh
# 6      Chitra Singh|Jagjit Singh
# 7                   Jagjit Singh
# 8                    Jagjit Kaur
# 9  Chitra Singh|Naseeruddin Shah
#
# ...

# %% [markdown]
# ### 1. Checking Null Values

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# ### 2. Data Preprocessing
# #### 2.1) Dealing with Duration

# %%
df['duration']
# Out:
# 0        05:00
# 1        06:26
# 2        03:41
# 3        04:26
# 4        05:39
#          ...
# 41350    03:23
# 41351    03:56
# 41352    07:36
# 41353    04:29
# 41354    03:22
# Name: duration, Length: 41355, dtype: object

# %%
for duration in df['duration'][:50]:
  print(duration, type(duration))  # we can see its a string type
# Out:
# 05:00 <class 'str'>
# 06:26 <class 'str'>
# 03:41 <class 'str'>
# 04:26 <class 'str'>
# 05:39 <class 'str'>
# 07:59 <class 'str'>
# 04:48 <class 'str'>
# 05:21 <class 'str'>
# 03:09 <class 'str'>
# 04:24 <class 'str'>
# 05:03 <class 'str'>
# 04:00 <class 'str'>
# 04:43 <class 'str'>
# 05:39 <class 'str'>
# 07:29 <class 'str'>
# 03:48 <class 'str'>
# 03:24 <class 'str'>
# 03:39 <class 'str'>
# 05:22 <class 'str'>
# 05:59 <class 'str'>
# 06:21 <class 'str'>
# 04:31 <class 'str'>
# 04:23 <class 'str'>
# 02:36 <class 'str'>
# 04:49 <class 'str'>
# 04:40 <class 'str'>
# 07:38 <class 'str'>
# 06:43 <class 'str'>
# 07:22 <class 'str'>
# 05:57 <class 'str'>
# 03:37 <class 'str'>
# 05:01 <class 'str'>
# 03:36 <class 'str'>
# 03:48 <class 'str'>
# 04:51 <class 'str'>
# 03:16 <class 'str'>
# 05:02 <class 'str'>
# 05:43 <class 'str'>
# 03:19 <class 'str'>
# 04:24 <class 'str'>
# 02:35 <class 'str'>
# 04:48 <class 'str'>
# 05:54 <class 'str'>
# 03:16 <class 'str'>
# 03:32 <class 'str'>
# ...

# %%
for duration in df['duration'][:50]:
  print(duration.split(':'))  # 0th index - minute
                              # 1st index - second
# Out:
# ['05', '00']
# ['06', '26']
# ['03', '41']
# ['04', '26']
# ['05', '39']
# ['07', '59']
# ['04', '48']
# ['05', '21']
# ['03', '09']
# ['04', '24']
# ['05', '03']
# ['04', '00']
# ['04', '43']
# ['05', '39']
# ['07', '29']
# ['03', '48']
# ['03', '24']
# ['03', '39']
# ['05', '22']
# ['05', '59']
# ['06', '21']
# ['04', '31']
# ['04', '23']
# ['02', '36']
# ['04', '49']
# ['04', '40']
# ['07', '38']
# ['06', '43']
# ['07', '22']
# ['05', '57']
# ['03', '37']
# ['05', '01']
# ['03', '36']
# ['03', '48']
# ['04', '51']
# ['03', '16']
# ['05', '02']
# ['05', '43']
# ['03', '19']
# ['04', '24']
# ['02', '35']
# ['04', '48']
# ['05', '54']
# ['03', '16']
# ['03', '32']
# ['03', '06']
# ['02', '35']
# ['04', '01']
# ['05', '07']
# ['03', '17']

# %%
# convert whole data into seconds
for duration in df['duration'][:50]:
  print(duration.split(':')[0],duration.split(':')[1])
# Out:
# 05 00
# 06 26
# 03 41
# 04 26
# 05 39
# 07 59
# 04 48
# 05 21
# 03 09
# 04 24
# 05 03
# 04 00
# 04 43
# 05 39
# 07 29
# 03 48
# 03 24
# 03 39
# 05 22
# 05 59
# 06 21
# 04 31
# 04 23
# 02 36
# 04 49
# 04 40
# 07 38
# 06 43
# 07 22
# 05 57
# 03 37
# 05 01
# 03 36
# 03 48
# 04 51
# 03 16
# 05 02
# 05 43
# 03 19
# 04 24
# 02 35
# 04 48
# 05 54
# 03 16
# 03 32
# 03 06
# 02 35
# 04 01
# 05 07
# 03 17

# %%
# next step - typecast it into integer
int('05')
# Out:
# 5

# %%
for duration in df['duration'][:50]:
  print('Min',int(duration.split(':')[0]))
  print('Sec',int(duration.split(':')[1]))
# Out:
# Min 5
# Sec 0
# Min 6
# Sec 26
# Min 3
# Sec 41
# Min 4
# Sec 26
# Min 5
# Sec 39
# Min 7
# Sec 59
# Min 4
# Sec 48
# Min 5
# Sec 21
# Min 3
# Sec 9
# Min 4
# Sec 24
# Min 5
# Sec 3
# Min 4
# Sec 0
# Min 4
# Sec 43
# Min 5
# Sec 39
# Min 7
# Sec 29
# Min 3
# Sec 48
# Min 3
# Sec 24
# Min 3
# Sec 39
# Min 5
# Sec 22
# Min 5
# Sec 59
# Min 6
# Sec 21
# Min 4
# Sec 31
# Min 4
# Sec 23
# Min 2
# Sec 36
# Min 4
# Sec 49
# Min 4
# Sec 40
# Min 7
# Sec 38
# Min 6
# Sec 43
# Min 7
# Sec 22
# Min 5
# Sec 57
# Min 3
# Sec 37
# Min 5
# Sec 1
# Min 3
# Sec 36
# Min 3
# Sec 48
# Min 4
# Sec 51
# Min 3
# Sec 16
# Min 5
# Sec 2
# Min 5
# Sec 43
# Min 3
# Sec 19
# Min 4
# Sec 24
# Min 2
# Sec 35
# Min 4
# Sec 48
# Min 5
# Sec 54
# Min 3
# Sec 16
# Min 3
# Sec 32
# Min 3
# Sec 6
# Min 2
# Sec 35
# Min 4
# Sec 1
# Min 5
# Sec 7
# Min 3
# Sec 17

# %%
duration_lst = []

for duration in df['duration']:
  m = int(duration.split(':')[0])
  s = int(duration.split(':')[1])
  sec = (m*60) + s
  print(m, s, sec)

  duration_lst.append(sec)

df['duration'] = duration_lst
df.head()
# Out:
# Streaming output truncated to the last 5000 lines.
# 2 42 162
# 3 53 233
# 3 27 207
# 4 9 249
# 9 29 569
# 4 26 266
# 4 16 256
# 3 23 203
# 3 3 183
# 4 45 285
# 5 49 349
# 3 45 225
# 2 54 174
# 4 40 280
# 3 54 234
# 4 35 275
# 3 4 184
# 3 36 216
# 4 7 247
# 4 28 268
# 1 5 65
# 4 7 247
# 4 4 244
# 4 6 246
# 7 31 451
# 6 0 360
# 3 57 237
# 5 49 349
# 59 21 3561
# 3 23 203
# 4 36 276
# 3 33 213
# 3 0 180
# 4 31 271
# 3 39 219
# 3 21 201
# 3 7 187
# 4 1 241
# 4 26 266
# 3 22 202
# 3 58 238
# 3 55 235
# 1 4 64
# 4 26 266
# 43 13 2593
# 4 27 267
# 4 38 278
# 5 48 348
# 3 47 227
# 4 16 256
# 4 35 275
# 6 26 386
# 4 46 286
# 4 39 279
# 3 11 191
# 4 5 245
# 0 54 54
# 0 54 54
# 4 43 283
# 4 24 264
# 5 22 322
# 6 3 363
# 2 9 129
# 1 44 104
# 5 6 306
# 3 2 182
# 3 26 206
# 3 18 198
# 4 22 262
# 3 12 192
# 3 48 228
# 3 31 211
# 3 24 204
# 4 59 299
# 3 34 214
# 3 57 237
# 4 39 279
# 3 57 237
# 4 26 266
# 4 54 294
# 24 22 1462
# 4 27 267
# 3 8 188
# 3 41 221
# 4 49 289
# 4 5 245
# 4 31 271
# ...

# %%
len(duration_lst)
# Out:
# 41355

# %% [markdown]
# ### 3. Data Analysis
# #### 3.1 Average duration of the song

# %%
print("Average duration of the song is", 
int(df['duration'].sum() / len(df['duration'])), 'seconds')
# Out:
# Average duration of the song is 295 seconds

# %%
# without using inbuilt function
s = 0
for i in df['duration']:
  s+= i
print(s/len(df['duration']))
# Out:
# 295.3130697618184

# %% [markdown]
# #### 3.2) How many languages of song are there in the dataset

# %%
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
df['language'].nunique()
# Out:
# 16

# %%
set(df['language']) #python function
# Out:
# {'Assamese',
#  'Bengali',
#  'Bhojpuri',
#  'Gujarati',
#  'Haryanvi',
#  'Hindi',
#  'Kannada',
#  'Malayalam',
#  'Marathi',
#  'Odia',
#  'Old',
#  'Punjabi',
#  'Rajasthani',
#  'Tamil',
#  'Telugu',
#  'Urdu'}

# %%
len(set(df['language']))
# Out:
# 16

# %% [markdown]
# ##### 3.3) What are all the language in the dataset?

# %%
for i in set(df['language']):
  print(i)
# Out:
# Telugu
# Bhojpuri
# Tamil
# Haryanvi
# Assamese
# Kannada
# Hindi
# Rajasthani
# Punjabi
# Old
# Malayalam
# Urdu
# Marathi
# Bengali
# Gujarati
# Odia

# %% [markdown]
# #### 3.4) How many punjabi songs are there?

# %%
c = 0
for i in df['language']:
  if(i=='Punjabi'): 
    c += 1 

print('There are',c,'songs in the Punjabi')
# Out:
# There are 3818 songs in the Punjabi

# %%
df[df['language'] == 'Punjabi']
# Out:
#                                              name  \
# 14236                          Pehle Lalkare Naal
# 14237                 Sharbat Wangu Ghut Bhar Lan
# 14238                              Jija Lak Minle
# 14239                            Laija Kithe Door
# 14240                        Das Meriya Dilwarave
# ...                                           ...
# 18049                                  I Love You
# 18050                         Aeh Dunya Lag Di Ae
# 18051  Nak Nathli Tey Akhan (From "Balocha Daku")
# 18052                       Main Kiyoon Na Tenoon
# 18053                            Jehra Karda Zulm
#
#                             singer  \
# 14236  Amar Singh Chamkila|Amarjot
# 14237  Amar Singh Chamkila|Amarjot
# 14238  Amar Singh Chamkila|Amarjot
# 14239  Amar Singh Chamkila|Amarjot
# 14240    Asha Bhosle|Mohammed Rafi
# ...                            ...
# 18049                 Nahid Akhtar
# 18050                   Noor Jehan
# ...

# %%
len(df[df['language'] == 'Punjabi'])
# Out:
# 3818

# %% [markdown]
# #### 3.5) Number of songs in each language?

# %%
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
c = 0
for i in df['language']:
  if(i=='Punjabi'): 
    c += 1 

print(c)
# Out:
# 3818

# %%
c = 0
for i in df['language']:
  if(i=='Urdu'): 
    c += 1 

print(c)
# Out:
# 3116

# %%
for lang in df['language'].unique():
  print(lang)
# Out:
# Urdu
# Gujarati
# Tamil
# Kannada
# Rajasthani
# Haryanvi
# Punjabi
# Hindi
# Old
# Malayalam
# Marathi
# Telugu
# Odia
# Bhojpuri
# Assamese
# Bengali

# %%
for lang in df['language'].unique():
    c = 0
    for i in df['language']:
      if(i=='lang'): 
        c += 1 

    print(lang, c)
# Out:
# Urdu 0
# Gujarati 0
# Tamil 0
# Kannada 0
# Rajasthani 0
# Haryanvi 0
# Punjabi 0
# Hindi 0
# Old 0
# Malayalam 0
# Marathi 0
# Telugu 0
# Odia 0
# Bhojpuri 0
# Assamese 0
# Bengali 0

# %%
# using the inbuild function
for lang in df['language'].unique():
  print(lang, len(df[df['language'] == lang]))
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4996
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %%
# Printing the dataframe
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %% [markdown]
# #### 3.6) Average duration of song in each language

# %%
for lang in df['language'].unique():
  
  print(df[df['language'] == lang]['duration'])
  break
# Out:
# 0       300
# 1       386
# 2       221
# 3       266
# 4       339
#        ...
# 3111    604
# 3112    371
# 3113    285
# 3114    376
# 3115    184
# Name: duration, Length: 3116, dtype: int64

# %%
for lang in df['language'].unique():
  
  print(df[df['language'] == lang]['duration'].mean())
  break
# Out:
# 407.2724646983312

# %%
for lang in df['language'].unique():
  
  print(lang, int(df[df['language'] == lang]['duration'].mean()))
  #break
# Out:
# Urdu 407
# Gujarati 271
# Tamil 270
# Kannada 250
# Rajasthani 291
# Haryanvi 320
# Punjabi 324
# Hindi 307
# Old 307
# Malayalam 242
# Marathi 281
# Telugu 279
# Odia 257
# Bhojpuri 357
# Assamese 228
# Bengali 255

# %% [markdown]
# #### 3.7) How many unique singers are there in the dataset?

# %%
for singers in df['singer'][:10]:
  print(singers)
# Out:
# Chitra Singh|Jagjit Singh
# Chitra Singh|Jagjit Singh
# Jagjit Singh
# Chitra Singh
# Jagjit Singh
# Chitra Singh|Jagjit Singh
# Chitra Singh|Jagjit Singh
# Jagjit Singh
# Jagjit Kaur
# Chitra Singh|Naseeruddin Shah

# %%
for singers in df['singer'][:10]:
  print(singers.split('|'))
# Out:
# ['Chitra Singh', 'Jagjit Singh']
# ['Chitra Singh', 'Jagjit Singh']
# ['Jagjit Singh']
# ['Chitra Singh']
# ['Jagjit Singh']
# ['Chitra Singh', 'Jagjit Singh']
# ['Chitra Singh', 'Jagjit Singh']
# ['Jagjit Singh']
# ['Jagjit Kaur']
# ['Chitra Singh', 'Naseeruddin Shah']

# %%
all_singer = []

for singers in df['singer'][:10]:
  all_singer += singers.split('|')
  print(singers.split('|'))
# Out:
# ['Chitra Singh', 'Jagjit Singh']
# ['Chitra Singh', 'Jagjit Singh']
# ['Jagjit Singh']
# ['Chitra Singh']
# ['Jagjit Singh']
# ['Chitra Singh', 'Jagjit Singh']
# ['Chitra Singh', 'Jagjit Singh']
# ['Jagjit Singh']
# ['Jagjit Kaur']
# ['Chitra Singh', 'Naseeruddin Shah']

# %%
all_singer  # appending all singer in one list
# Out:
# ['Chitra Singh',
#  'Jagjit Singh',
#  'Chitra Singh',
#  'Jagjit Singh',
#  'Jagjit Singh',
#  'Chitra Singh',
#  'Jagjit Singh',
#  'Chitra Singh',
#  'Jagjit Singh',
#  'Chitra Singh',
#  'Jagjit Singh',
#  'Jagjit Singh',
#  'Jagjit Kaur',
#  'Chitra Singh',
#  'Naseeruddin Shah']

# %%
# now find the unique singer from the list
all_singer = []

for singers in df['singer']:
  all_singer += singers.split('|')

print('Total Singers:', len(set(all_singer)))
# Out:
# Total Singers: 3940

# %%
len(all_singer)
# Out:
# 60166

# %%
len(set(all_singer))
# Out:
# 3940

# %% [markdown]
# #### 3.8) Who has the most number of song played?

# %%
unique_singers = list(set(all_singer))

for i in unique_singers[:10]:

  c = 0
  for singers_ in df['singer']:
    if(i in singers_):
      c += 1
  print(i,c)
# Out:
# Vaman Kardak 7
# Anil Kumar 4
# Nellai S.M.Abul Barakath 1
# Viraj 3
# K V  Mahadevan 2
# Khan Mohd. 1
# Sarabjeet Sharma 2
# Sushree Sangeeta Mahapatra 5
# Arati Basu 2
# Varsha Suresh 2

# %%
c = 0
for i in df['singer']:
  if ('Jagjit Singh' == i):
    c += 1
print(c)
# Out:
# 172

# %%
c = 0
for i in df['singer']:
  if ('Jagjit Singh' in i):
    c += 1
print(c)
# Out:
# 255

# %%
data = []

unique_singers = list(set(all_singer))

for i in tqdm(unique_singers):

  c = 0
  for singers_ in df['singer']:
    if(i in singers_):
      c += 1

  data.append((i,c))
# Out:
# 100%|██████████| 3940/3940 [00:33<00:00, 116.99it/s]

# %%
songs = pd.DataFrame()

# %%
len(data)
data[0]
# Out:
# ('Vaman Kardak', 7)

# %%
songs = pd.DataFrame(data, columns= ['singer', 'songs'])
songs.head()
# Out:
#                      singer  songs
# 0              Vaman Kardak      7
# 1                Anil Kumar      4
# 2  Nellai S.M.Abul Barakath      1
# 3                     Viraj      3
# 4            K V  Mahadevan      2

# %%
songs.sort_values(by = 'songs')
# Out:
#                       singer  songs
# 3939              Nilima Sen      1
# 1061                B. Radha      1
# 2495               Siddaramu      1
# 2498              I. Shravya      1
# 1056           Rani Rooplata      1
# ...                      ...    ...
# 1130             P. Susheela   3213
# 2697                Susheela   3215
# 1299                 Susheel   3216
# 1872                   Kumar   3270
# 2672  S. P. Balasubrahmanyam   3659
#
# [3940 rows x 2 columns]

# %%
songs.sort_values(by = 'songs', ascending = False).head()  # singer sung the most number of song
# Out:
#                       singer  songs
# 2672  S. P. Balasubrahmanyam   3659
# 1872                   Kumar   3270
# 1299                 Susheel   3216
# 2697                Susheela   3215
# 1130             P. Susheela   3213

# %% [markdown]
# #### 3.9) Singer who played most number of song in each language

# %%
for lang in df['language'].unique():
  df_ = df[df['language'] == lang]

  all_singer = []

  for singers in df_['singer']:
    all_singer += singers.split('|')

  print(lang, len(df_), len(set(all_singer))) # lang, song, singer
# Out:
# Urdu 3116 385
# Gujarati 2115 303
# Tamil 4677 510
# Kannada 3559 379
# Rajasthani 541 218
# Haryanvi 228 76
# Punjabi 3818 636
# Hindi 4993 515
# Old 4993 515
# Malayalam 479 72
# Marathi 4699 569
# Telugu 4996 369
# Odia 940 243
# Bhojpuri 519 109
# Assamese 724 228
# Bengali 958 192
